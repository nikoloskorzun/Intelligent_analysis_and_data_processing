# %% [markdown]
# # Самый лучший результат гридсерча

# %% [markdown]
# ## MLP
#
#
# df_enhanced.csv_scaled.csv; {'input_shape': 58, 'num_classes': 7, 'optimizer': 'sgd', 'learning_rate': 0.0001, 'dense_units': [128, 64], 'kernel_size': 3, 'pool_size': 2, 'use_batch_norm': True, 'filters': [128, 256]};train; acc= 0.8087842441066638;
# train; bal_acc= 0.7590172321973773;
# train; f1_macro= 0.6963648684049638;
# train; f1_weighted= 0.8119926874180305;
# train; classification_report=               precision    recall  f1-score   support
#
#      Class 1       0.81      0.78      0.79    129155
#      Class 2       0.85      0.84      0.84    179287
#      Class 3       0.87      0.74      0.80     22864
#      Class 4       0.58      0.74      0.65      1519
#      Class 5       0.29      0.64      0.40      3002
#      Class 6       0.47      0.70      0.57      6988
#      Class 7       0.77      0.87      0.82     10932
#
#     accuracy                           0.81    353747
#    macro avg       0.66      0.76      0.70    353747
# weighted avg       0.82      0.81      0.81    353747
# ;
# test; acc= 0.8076896439136845;
# test; bal_acc= 0.7591048820322795;
# test; f1_macro= 0.6936510973421953;
# test; f1_weighted= 0.8110666093357081;
# test; classification_report=               precision    recall  f1-score   support
#
#      Class 1       0.81      0.78      0.79     36793
#      Class 2       0.85      0.84      0.84     51278
#      Class 3       0.87      0.75      0.81      6658
#      Class 4       0.56      0.72      0.63       420
#      Class 5       0.29      0.64      0.40       841
#      Class 6       0.46      0.71      0.56      1987
#      Class 7       0.77      0.87      0.82      3094
#
#     accuracy                           0.81    101071
#    macro avg       0.66      0.76      0.69    101071
# weighted avg       0.82      0.81      0.81    101071
# ;
# valid; acc= 0.8068703498496121;
# valid; bal_acc= 0.755394682167262;
# valid; f1_macro= 0.6939771588219859;
# valid; f1_weighted= 0.810061846826458;
# valid; classification_report=               precision    recall  f1-score   support
#
#      Class 1       0.81      0.78      0.79     18650
#      Class 2       0.84      0.84      0.84     25492
#      Class 3       0.87      0.75      0.80      3195
#      Class 4       0.58      0.75      0.65       219
#      Class 5       0.28      0.63      0.38       405
#      Class 6       0.48      0.68      0.57      1016
#      Class 7       0.78      0.86      0.82      1559
#
#     accuracy                           0.81     50536
#    macro avg       0.66      0.76      0.69     50536
# weighted avg       0.82      0.81      0.81     50536
# ;

# %% [markdown]
# ## 1d_cnn
# Не зря датасет обрабатывали и данные подготовливаои!
#
#
# df_enhanced.csv_selected_features.csv_scaled.csv; {'input_shape': 12, 'num_classes': 7, 'optimizer': 'adam', 'learning_rate': 0.0001, 'dense_units': [128, 64, 32], 'kernel_size': 3, 'pool_size': 2, 'use_batch_norm': True, 'filters': [64, 128, 256]};train; acc= 0.8667041699293563;
# train; bal_acc= 0.8293007120889824;
# train; f1_macro= 0.8085568910359997;
# train; f1_weighted= 0.8673741428458442;
# train; classification_report=               precision    recall  f1-score   support
#
#      Class 1       0.85      0.85      0.85    124241
#      Class 2       0.90      0.88      0.89    180980
#      Class 3       0.88      0.85      0.87     20182
#      Class 4       0.72      0.75      0.73      1841
#      Class 5       0.60      0.77      0.67      5090
#      Class 6       0.73      0.81      0.77      9319
#      Class 7       0.87      0.89      0.88     12094
#
#     accuracy                           0.87    353747
#    macro avg       0.79      0.83      0.81    353747
# weighted avg       0.87      0.87      0.87    353747
# ;
# test; acc= 0.8618100147421119;
# test; bal_acc= 0.8200776288134828;
# test; f1_macro= 0.7971317537355931;
# test; f1_weighted= 0.8625497584444218;
# test; classification_report=               precision    recall  f1-score   support
#
#      Class 1       0.84      0.85      0.85     35338
#      Class 2       0.89      0.88      0.89     51751
#      Class 3       0.87      0.85      0.86      5909
#      Class 4       0.67      0.72      0.69       494
#      Class 5       0.59      0.75      0.66      1451
#      Class 6       0.72      0.81      0.76      2698
#      Class 7       0.87      0.88      0.88      3430
#
#     accuracy                           0.86    101071
#    macro avg       0.78      0.82      0.80    101071
# weighted avg       0.86      0.86      0.86    101071
# ;
# valid; acc= 0.8627117302517018;
# valid; bal_acc= 0.8214155650114856;
# valid; f1_macro= 0.7989785481402507;
# valid; f1_weighted= 0.8634472401641747;
# valid; classification_report=               precision    recall  f1-score   support
#
#      Class 1       0.84      0.85      0.85     17857
#      Class 2       0.90      0.88      0.89     25891
#      Class 3       0.87      0.85      0.86      2795
#      Class 4       0.70      0.75      0.72       261
#      Class 5       0.58      0.76      0.66       708
#      Class 6       0.72      0.78      0.75      1320
#      Class 7       0.86      0.87      0.87      1704
#
#     accuracy                           0.86     50536
#    macro avg       0.78      0.82      0.80     50536
# weighted avg       0.86      0.86      0.86     50536
# ;

# %% [markdown]
# Еще по подираем исходя из гридсерча и увеличим число эпох обчучения.
# И вот наш результат!
#
# 0 {'input_shape': 12, 'num_classes': 7, 'optimizer': 'adam', 'learning_rate': 0.0001, 'dense_units': [128, 64, 32], 'kernel_size': 3, 'pool_size': 1, 'use_batch_norm': True, 'filters': [16, 32, 64, 128, 256]}
#
# train; acc= 0.9300630111350767;
# train; bal_acc= 0.8975952463209149;
# train; f1_macro= 0.893941163044181;
# train; f1_weighted= 0.9301073922287543;
# train; classification_report=               precision    recall  f1-score   support
#
#      Class 1       0.92      0.93      0.92    124004
#      Class 2       0.95      0.94      0.94    179428
#      Class 3       0.93      0.92      0.93     19638
#      Class 4       0.79      0.82      0.81      1860
#      Class 5       0.85      0.82      0.83      6765
#      Class 6       0.86      0.91      0.88      9842
#      Class 7       0.94      0.95      0.94     12210
#
#     accuracy                           0.93    353747
#    macro avg       0.89      0.90      0.89    353747
# weighted avg       0.93      0.93      0.93    353747
# ;
# test; acc= 0.9175332192221309;
# test; bal_acc= 0.8713998419191481;
# test; f1_macro= 0.8695236485272656;
# test; f1_weighted= 0.9176029993594275;
# test; classification_report=               precision    recall  f1-score   support
#
#      Class 1       0.90      0.92      0.91     35149
#      Class 2       0.94      0.93      0.93     51350
#      Class 3       0.91      0.91      0.91      5777
#      Class 4       0.75      0.75      0.75       538
#      Class 5       0.81      0.78      0.80      1926
#      Class 6       0.83      0.88      0.85      2842
#      Class 7       0.93      0.93      0.93      3489
#
#     accuracy                           0.92    101071
#    macro avg       0.87      0.87      0.87    101071
# weighted avg       0.92      0.92      0.92    101071
# ;
# valid; acc= 0.918711413645718;
# valid; bal_acc= 0.8778516629228813;
# valid; f1_macro= 0.8729487343235162;
# valid; f1_weighted= 0.9188184749963217;
# valid; classification_report=               precision    recall  f1-score   support
#
#      Class 1       0.91      0.92      0.91     17814
#      Class 2       0.94      0.93      0.93     25677
#      Class 3       0.91      0.91      0.91      2779
#      Class 4       0.76      0.78      0.77       275
#      Class 5       0.81      0.80      0.80       939
#      Class 6       0.82      0.89      0.85      1335
#      Class 7       0.93      0.93      0.93      1717
#
#     accuracy                           0.92     50536
#    macro avg       0.87      0.88      0.87     50536
# weighted avg       0.92      0.92      0.92     50536
